# %% [markdown]
# # Read_csv Parameters

# %% [markdown]
# ### Opening csv file from an URL

# %%
import pandas as pd

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

# %%
# 1) sep parameter --> for example tab se seperate data ko load kar sakte hai
# 2) index_col --> kisi bhi column ko agar index banana hai to
# 3)* names = ['col1','col2'] --> columns k name dene k liye if vo 1st row ko hi header ki tarah treat kar raha hai ho
# 4)* header = 1 --> if apka header row ban gaya hai or headers me unnamed aa raha hai to ye use karke 1st row ko as a header rakh sakte hai
# 5) use_cols = ['col1','col4','col5'] --> if hum data ko load karte time hi kuch specific data columns hi chahte hai to vo likh sakte hai
# 6) squeeze = True --> column ko serires ki tarah treat karega
# 7) skiprows = [0,2] --> hum specific rows skip kar sakte hai / isme hum lambda function bhi use kar sakte hai to filter entire data
# 8) nrows = 100 --> agar hum 100 rows ka data hi chahte hai 
# 9) encoding = 'latin-1' --> zomato.csv jese data ko agar hum load karenge to usme "unicodeDecodeError" aayega bcoz vo data utf-8 encoded nahi hota to hum ye use kar sakte hai
# 10) error_bad_lines = False --> kuch data set aese hote jisme pehle 5 entries hoti hai column me phir 6 or 7 or 8 so isko handle karne k liye ye param unn sari rows ko delete kar deta hai (BX-Books.csv)
# 11)* dtype = {'target':int} --> target column ko int me convert karega for memory utilization
# 12)* parse_dates = ['date'] --> convert date column str to date format or you can combine diff month and year column as newdate => parse_dates = {'newdate':[1,3]} #index of that cols
# 13) converters = {'target_col':func_name} --> jo bhi aapki target column hai usko uss function ke according convert kar dega
# 14)* na_values = ['-','Not Available'] --> in sari entries ko vo as a NaN values treat karega
# 15)* chunksize = 5000 --> data ko equally chunks me divide kar dega for example => df = pd.read_csv("aug_train.csv",chunksize = 5000)
#                                                                                    for i in df:
#                                                                                        print(i.shape)
#                                                                                    output => 194 rows => (50, 2)  (50, 2)  (50, 2)  (44, 2)

# %%
dfs = pd.read_csv(data,chunksize = 50)
for i in dfs:
    print(i.shape)
# Out:
# (50, 2)
# (50, 2)
# (50, 2)
# (44, 2)

# %% [markdown]
# # Read JSON

# %%
df = pd.read_json("filename.json")
df = pd.read_json("url of dataset")

# %% [markdown]
# # Read SQL

# %%
# steps :
# 1) start Apache and mysql on XAMPP
# 2) in chrome type localhost/phpmyadmin
# 3) new --> database name --> create
# 4) download .sql dataset from kaggle
# 5) in phpmy admin import menu --> choose file --> import

# %%
import pandas as pd
import mysql.connector

# %%
conn = mysql.connector.connect(host = "localhost",user = "root",password = '',database = "world")

# %%
pd.read_sql("SELECT * FROM city",conn)
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_25248\2233522383.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM city",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
pd.read_sql("SELECT * FROM city WHERE CountryCode like 'IND' ",conn)
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_25248\246220210.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM city WHERE CountryCode like 'IND' ",conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# ...

# %%
pd.read_sql("SELECT * FROM country",conn)
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_25248\1407656816.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT * FROM country",conn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %% [markdown]
# # API

# %%
import requests

url = "https://linkedin-data-api.p.rapidapi.com/get-company-by-domain"
querystring = {"domain": "apple.com"}

headers = {
    "x-rapidapi-host": "linkedin-data-api.p.rapidapi.com",
    "x-rapidapi-key": "c609129fa3msh2c4881813e8336dp136111jsn64f2ac55cc46"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())  # prints the API response as JSON
# Out:
# {'message': 'You are not subscribed to this API.'}
